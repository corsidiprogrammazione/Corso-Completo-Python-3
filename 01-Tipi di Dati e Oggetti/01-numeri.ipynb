# %%
2 + 2
# Out:
# 4

# %%
3 - 2
# Out:
# 1

# %%
2 * 2
# Out:
# 4

# %%
6 / 3
# Out:
# 2.0

# %%
7 % 3
# Out:
# 1

# %%
20 % 2
# Out:
# 0

# %%
11 % 2
# Out:
# 1

# %%
10 % 2
# Out:
# 0

# %%
2 ** 3
# Out:
# 8

# %%
3 + 4 * 4 + 5
# Out:
# 24

# %%
(3 + 4) * (4 + 5)
# Out:
# 63

# %%
3 * 3.75 / 1.5
# Out:
# 7.5

# %%
7.0 / 2
# Out:
# 3.5
