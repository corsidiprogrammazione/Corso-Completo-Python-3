# %%
2 == 2
# Out:
# True

# %%
3 == 5
# Out:
# False

# %%
'ciao' == 'ciao'
# Out:
# True

# %%
'ciao' == 'Ciao'
# Out:
# False

# %%
'3' == 3
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
2.1 == 2
# Out:
# False

# %%
4 != 4
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
5 > 4
# Out:
# True

# %%
5 > 9
# Out:
# False

# %%
4 < 3
# Out:
# False

# %%
4 >= 4
# Out:
# True

# %%
4 >= 3
# Out:
# True

# %%
2 >= 3
# Out:
# False

# %%
4 <= 3
# Out:
# False

# %%
2 <= 2
# Out:
# True

# %%
1 < 2
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
1 < 3 and 'ciao' == 'ciao'
# Out:
# True

# %%
(1 < 3) and ('ciao' == 'ciao')
# Out:
# True

# %%
(1 == 2) or (2 == 2)
# Out:
# True

# %%
(1 == 2) or (2 == 3)
# Out:
# False

# %%
3 == 3
# Out:
# True

# %%
not(3 == 3)
# Out:
# False
