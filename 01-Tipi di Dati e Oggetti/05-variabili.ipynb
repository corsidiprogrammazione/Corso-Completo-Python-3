# %%
a = 3

# %%
a
# Out:
# 3

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a + a
# Out:
# 10

# %%
a
# Out:
# 5

# %%
a = a + a

# %%
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
a = 10.5

# %%
type(a)
# Out:
# float

# %%
tassa = 12.5 / 100
prezzo = 100.50
prezzo * tassa
# Out:
# 12.5625

# %%
prezzo + _
# Out:
# 113.0625

# %%
round(_,2)
# Out:
# 113.06

# %%
a,b,c = 1,2.5,'tre'

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2.5

# %%
c
# Out:
# 'tre'

# %%
a = b = c = 4

# %%
a
# Out:
# 4

# %%
b
# Out:
# 4

# %%
c
# Out:
# 4
