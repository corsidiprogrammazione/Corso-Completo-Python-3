# %%
import pandas

# %%
dati = pandas.DataFrame([[1,2,3],[10,20,30]])
dati
# Out:
#     0   1   2
# 0   1   2   3
# 1  10  20  30

# %%
dati = pandas.DataFrame([[1,2,3],[10,20,30]],columns=['A','B','C'],index=['RIGA1','RIGA2'])
dati
# Out:
#         A   B   C
# RIGA1   1   2   3
# RIGA2  10  20  30

# %%
dati2 = pandas.DataFrame([{"nome":"Angelo","cognome":"Rossi"},{"nome":"Michele","cognome":"Neri"}])
dati2
# Out:
#   cognome     nome
# 0   Rossi   Angelo
# 1    Neri  Michele

# %%
type(dati)
# Out:
# pandas.core.frame.DataFrame

# %%
dati.mean().mean()
# Out:
# 11.0

# %%
dati.B.mean()
# Out:
# 11.0

# %%
import os
os.listdir()
# Out:
# ['bollette.json',
#  'Lezione_Gestire_i_Dati_con_Pandas.ipynb',
#  '.DS_Store',
#  '.localized',
#  'bollette.csv',
#  'bollette_virgola.txt',
#  'bollette_ID.csv',
#  'bollette_punto_virgola.txt',
#  '.ipynb_checkpoints',
#  'Programmi',
#  'bollette.xlsx']

# %%
dati_csv = pandas.read_csv("bollette.csv",header=None)
dati_csv
# Out:
#            0       1
# 0   Bollette  Prezzo
# 1        GAS     100
# 2      ACQUA     200
# 3       LUCE     100
# 4   INTERNET      25
# 5        NaN     NaN
# 6        NaN     NaN
# 7        NaN     NaN
# 8        NaN     NaN
# 9        NaN     NaN
# 10       NaN     NaN
# 11       NaN     NaN
# 12       NaN     NaN
# 13       NaN     NaN
# 14       NaN     NaN
# 15       NaN     NaN
# 16       NaN     NaN
# 17       NaN     NaN
# 18       NaN     NaN
# 19       NaN     NaN
# 20    Totale     425

# %%
dati_csv.shape
# Out:
# (21, 2)

# %%
dati_json = pandas.read_json("bollette.json")
dati_json
# Out:
#    Bollette    Prezzo
# 0       GAS  100,00 €
# 1     ACQUA  200,00 €
# 2      LUCE  100,00 €
# 3  INTERNET   25,00 €
# 4    TOTALE  425,00 €

# %%
dati_excel = pandas.read_excel("bollette.xlsx",sheet=0)
dati_excel
# Out:
#     Bollette  Prezzo
# 0        GAS   100.0
# 1      ACQUA   200.0
# 2       LUCE   100.0
# 3   INTERNET    25.0
# 4        NaN     NaN
# 5        NaN     NaN
# 6        NaN     NaN
# 7        NaN     NaN
# 8        NaN     NaN
# 9        NaN     NaN
# 10       NaN     NaN
# 11       NaN     NaN
# 12       NaN     NaN
# 13       NaN     NaN
# 14       NaN     NaN
# 15       NaN     NaN
# 16       NaN     NaN
# 17       NaN     NaN
# 18       NaN     NaN
# 19    Totale   425.0

# %%
dati_txt_v = pandas.read_csv("bollette_virgola.txt")
dati_txt_v
# Out:
#     Bollette   Prezzo
# 1        GAS  100.00€
# 2      ACQUA  200.00€
# 3       LUCE  100.00€
# 4   INTERNET   25.00€
# 5        NaN      NaN
# 6        NaN      NaN
# 7        NaN      NaN
# 8        NaN      NaN
# 9        NaN      NaN
# 10       NaN      NaN
# 11       NaN      NaN
# 12       NaN      NaN
# 13       NaN      NaN
# 14       NaN      NaN
# 15       NaN      NaN
# 16       NaN      NaN
# 17       NaN      NaN
# 18       NaN      NaN
# 19       NaN      NaN
# 20       NaN      NaN
# 21    TOTALE  425.00€

# %%
dati_txt_pv = pandas.read_csv("bollette_punto_virgola.txt",sep=";")
dati_txt_pv
# Out:
#     Bollette   Prezzo
# 1        GAS  100.00€
# 2      ACQUA  200.00€
# 3       LUCE  100.00€
# 4   INTERNET   25.00€
# 5        NaN      NaN
# 6        NaN      NaN
# 7        NaN      NaN
# 8        NaN      NaN
# 9        NaN      NaN
# 10       NaN      NaN
# 11       NaN      NaN
# 12       NaN      NaN
# 13       NaN      NaN
# 14       NaN      NaN
# 15       NaN      NaN
# 16       NaN      NaN
# 17       NaN      NaN
# 18       NaN      NaN
# 19       NaN      NaN
# 20       NaN      NaN
# 21    TOTALE  425.00€

# %%
dati_txt_id = pandas.read_csv("bollette_ID.csv")
dati_txt_id
# Out:
#    ID  Bollette  Prezzo
# 0   1       GAS     100
# 1   2     ACQUA     200
# 2   3      LUCE     100
# 3   4  INTERNET      25
# 4   5    Totale     425

# %%
dati_txt_id = dati_txt_id.set_index("ID")
dati_txt_id
# Out:
#     Bollette  Prezzo
# ID
# 1        GAS     100
# 2      ACQUA     200
# 3       LUCE     100
# 4   INTERNET      25
# 5     Totale     425

# %%
dati_txt_id.loc[1]
# Out:
# Bollette    GAS
# Prezzo      100
# Name: 1, dtype: object

# %%
dati_txt_id.loc[4]
# Out:
# Bollette    INTERNET
# Prezzo            25
# Name: 4, dtype: object

# %%
dati_txt_id.loc[2:4,"Prezzo"]
# Out:
# ID
# 2    200
# 3    100
# 4     25
# Name: Prezzo, dtype: int64

# %%
dati_txt_id.loc[2,"Prezzo"]
# Out:
# 200

# %%
dati_txt_id['VALUTA'] = "€"
dati_txt_id
# Out:
#     Bollette  Prezzo VALUTA
# ID
# 1        GAS     100      €
# 2      ACQUA     200      €
# 3       LUCE     100      €
# 4   INTERNET      25      €
# 5     Totale     425      €

# %%
dati_txt_id["VALUTA"] = dati_txt_id["Prezzo"].apply(str) + " €"
dati_txt_id
# Out:
#     Bollette  Prezzo VALUTA
# ID
# 1        GAS     100  100 €
# 2      ACQUA     200  200 €
# 3       LUCE     100  100 €
# 4   INTERNET      25   25 €
# 5     Totale     425  425 €

# %%
dati_txt_id.loc[6] = ["Nuova",0,"0 €"]
dati_txt_id
# Out:
#     Bollette  Prezzo VALUTA
# ID
# 1        GAS     100  100 €
# 2      ACQUA     200  200 €
# 3       LUCE     100  100 €
# 4   INTERNET      25   25 €
# 5     Totale     425  425 €
# 6      Nuova       0    0 €

# %%
dati_txt_id.T.shape
# Out:
# (3, 6)

# %%
dati_txt_id
# Out:
#     Bollette  Prezzo VALUTA
# ID
# 1        GAS     100  100 €
# 2      ACQUA     200  200 €
# 3       LUCE     100  100 €
# 4   INTERNET      25   25 €
# 5     Totale     425  425 €
# 6      Nuova       0    0 €

# %%
dati_txt_id.drop("Prezzo",1)
# Out:
#     Bollette VALUTA
# ID
# 1        GAS  100 €
# 2      ACQUA  200 €
# 3       LUCE  100 €
# 4   INTERNET   25 €
# 5     Totale  425 €
# 6      Nuova    0 €

# %%
dati_txt_id.drop(3,0)
# Out:
#     Bollette  Prezzo VALUTA
# ID
# 1        GAS     100  100 €
# 2      ACQUA     200  200 €
# 4   INTERNET      25   25 €
# 5     Totale     425  425 €
# 6      Nuova       0    0 €

# %%
dati_txt_id
# Out:
#     Bollette  Prezzo VALUTA
# ID
# 1        GAS     100  100 €
# 2      ACQUA     200  200 €
# 3       LUCE     100  100 €
# 4   INTERNET      25   25 €
# 5     Totale     425  425 €
# 6      Nuova       0    0 €

# %%
dati_txt_id.iloc[2:6,1:3]
# Out:
#     Prezzo VALUTA
# ID
# 3      100  100 €
# 4       25   25 €
# 5      425  425 €
# 6        0    0 €
